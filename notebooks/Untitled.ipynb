# %%
import pointCollection as pc

# %%
temp=pc.grid.data().from_file('downloads/S2B_13CES_20200201_B04.tif')

# %%
temp
# Out:
# <class 'pointCollection.grid.data.data'> with shape [3595, 3985],
# with fields:
# ['z']

# %%
temp.show()

# %%
temp.z[0:10, 0:10]
# Out:
# array([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]])
